# %%
import pandas as pd
from proxy_requests import ProxyRequests
import requests
from bs4 import BeautifulSoup as soup
import json
import time
import pathlib

# %%
def urls_to_json_yield(urls):
    for url in urls:
        r = ProxyRequests(url)
        r.get()
        page = soup(r.get_raw(), "html.parser")
        fixture_data = page.find("div",{"class":"mcTabsContainer"})["data-fixture"]
        yield fixture_data

# %%
base_url = "https://www.premierleague.com/match/"
urls0607_1415 = [base_url + str(i) for i in range(5567,9991)] # 5567 to 9990 inclusive
urls1516 = [base_url + str(i) for i in range(12115,12495)] # 12115 to 12494 inclusive
urls1617 = [base_url + str(i) for i in range(14040,14420)] # 14040 to 14419 inclusive
urls1718 = [base_url + str(i) for i in range(22342,22722)] # 22342 to 22721 inclusive
urls1819 = [base_url + str(i) for i in range(38308,38688)] # 38308 to 38687 inclusive
urls1920 = [base_url + str(i) for i in range(46605,46985)] # 46605 to 46984 inclusive
urls = urls0607_1415 + urls1516 + urls1617 + urls1718 + urls1819 + urls1920

# %%
test_set = [base_url + str(i) for i in range(5567,5571)] # 4 matches, 5567, 5568, 5569, 5570
test_set
# Out:
# ['https://www.premierleague.com/match/5567',
#  'https://www.premierleague.com/match/5568',
#  'https://www.premierleague.com/match/5569',
#  'https://www.premierleague.com/match/5570']

# %%
test_fixture_data_yielder = urls_to_json_yield(test_set)

# %%
def yield_then_store(generator_function):
    json_data_from_generator = next(generator_function)
    json_data = json.loads(json_data_from_generator)
    gameweek_data = json_data["gameweek"]
    season = gameweek_data["compSeason"]["label"]
    season_formatted = season.replace("/","")
    gameweek = gameweek_data["gameweek"]
    id_ = json_data["id"]
    filename = str("data/") + str(season_formatted) + "_" + str(gameweek) + "_" + str(id_) + ".json"
    with open(filename, 'w') as json_file:
        json.dump(json_data, json_file)

# %%
for i in range(len(test_set)):
    yield_then_store(test_fixture_data_yielder)

# %%
def yield_then_store_by_gameweek(generator_function,first_gameweek):
    current_gameweek = first_gameweek
    final_data = {}
    while True:
        try:
            json_data_from_generator = next(generator_function)
        except:
            break
        json_data = json.loads(json_data_from_generator)
        gameweek_data = json_data["gameweek"]
        # "if not prem, skip" check
        competition = str(gameweek_data["compSeason"]["competition"]["abbreviation"])
        if competition == "EN_PR":
            gameweek = str(gameweek_data["gameweek"])
            if gameweek == current_gameweek:
                season = gameweek_data["compSeason"]["label"]
                season_formatted = season.replace("/","")
                id_ = json_data["id"]
                final_data[str(id_)] = json_data
            else:
                tagline = str("data/") + str(season_formatted) + "_" + str(current_gameweek)
                filename = tagline + ".json"
                path = pathlib.Path(filename)
                while path.exists():
                    new_tagline = tagline + "_"
                    tagline = new_tagline
                    filename = tagline + ".json"
                    path = pathlib.Path(filename)
                with open(filename, 'w') as json_file:
                    json.dump(final_data, json_file)
                print("Gameweek {} complete, stored as {}".format(current_gameweek,filename))
                current_gameweek = gameweek
            
                # Then redo all the work for this current match, which is part of a new gameweek
                season = gameweek_data["compSeason"]["label"]
                season_formatted = season.replace("/","")
                id_ = json_data["id"]
                final_data = {}
                final_data[str(id_)] = json_data
        else:
            print("Non prem game found (Id:{}): Competition = {}".format(json_data["id"],competition))
    # Store all extra data not yet stored if there is any
    if final_data != {}:
        tagline = str("data/") + str(season_formatted) + "_" + str(current_gameweek)
        filename = tagline + ".json"
        path = pathlib.Path(filename)
        while path.exists():
            new_tagline = tagline + "_"
            tagline = new_tagline
            filename = tagline + ".json"
            path = pathlib.Path(filename)
        with open(filename, 'w') as json_file:
            json.dump(final_data, json_file)
    print("Final ID Saved: {}".format(id_))
    print("Done")

# %%
test_set_2 = [base_url + str(i) for i in range(5567,5590)] # 23 matches, should have 3 files, 240kb, 240kb and 72 kb ish.

# %%
import time
t1 = time.time()
test_2_fixture_data_yielder = urls_to_json_yield(test_set_2)
yield_then_store_by_gameweek(test_2_fixture_data_yielder)
t2 = time.time()
print("Took {} seconds".format(round(t2-t1,2)))
# Out:
# Gameweek 1 complete, stored as data/200607_1.json
# Gameweek 2 complete, stored as data/200607_2.json
# Done
# Took 603.96 seconds

# %%
big_test_set = [base_url + str(i) for i in range(5585,6500)]
t1 = time.time()
big_test_yielder = urls_to_json_yield(big_test_set)
yield_then_store_by_gameweek(big_test_yielder)
t2 = time.time()
print("Took {} seconds".format(round(t2-t1,2)))
# Out:
# Gameweek 3 complete, stored as data/200607_3.json
# Gameweek 4 complete, stored as data/200607_4.json
# Gameweek 5 complete, stored as data/200607_5.json
# Gameweek 6 complete, stored as data/200607_6.json
# Gameweek 7 complete, stored as data/200607_7.json
# Gameweek 8 complete, stored as data/200607_8.json
# Gameweek 9 complete, stored as data/200607_9.json
# Gameweek 10 complete, stored as data/200607_10.json
# Gameweek 11 complete, stored as data/200607_11.json
# Gameweek 12 complete, stored as data/200607_12.json
# Gameweek 13 complete, stored as data/200607_13.json
# Gameweek 14 complete, stored as data/200607_14.json
# Gameweek 15 complete, stored as data/200607_15.json
# Gameweek 16 complete, stored as data/200607_16.json
# Gameweek 17 complete, stored as data/200607_17.json
# Gameweek 18 complete, stored as data/200607_18.json
# Gameweek 19 complete, stored as data/200607_19.json
# Gameweek 20 complete, stored as data/200607_20.json
# Gameweek 21 complete, stored as data/200607_21.json
# Gameweek 22 complete, stored as data/200607_22.json
# Gameweek 23 complete, stored as data/200607_23.json
# Gameweek 24 complete, stored as data/200607_24.json
# Gameweek 25 complete, stored as data/200607_25.json
# Gameweek 26 complete, stored as data/200607_26.json
# Gameweek 27 complete, stored as data/200607_27.json
# Gameweek 28 complete, stored as data/200607_28.json
# Gameweek 29 complete, stored as data/200607_29.json
# Gameweek 30 complete, stored as data/200607_30.json
# Gameweek 31 complete, stored as data/200607_31.json
# Gameweek 32 complete, stored as data/200607_32.json
# Gameweek 33 complete, stored as data/200607_33.json
# Gameweek 34 complete, stored as data/200607_34.json
# Gameweek 35 complete, stored as data/200607_35.json
# Gameweek 36 complete, stored as data/200607_36.json
# Gameweek 37 complete, stored as data/200607_37.json
# Gameweek 38 complete, stored as data/200607_38.json
# Gameweek 39 complete, stored as data/200607_39.json
# Gameweek 1 complete, stored as data/200708_1.json
# Gameweek 2 complete, stored as data/200708_2.json
# Gameweek 3 complete, stored as data/200708_3.json
# Gameweek 4 complete, stored as data/200708_4.json
# Gameweek 5 complete, stored as data/200708_5.json
# Gameweek 6 complete, stored as data/200708_6.json
# Gameweek 7 complete, stored as data/200708_7.json
# Gameweek 8 complete, stored as data/200708_8.json
# Gameweek 9 complete, stored as data/200708_9.json
# Gameweek 10 complete, stored as data/200708_10.json
# Gameweek 11 complete, stored as data/200708_11.json
# Gameweek 12 complete, stored as data/200708_12.json
# Gameweek 13 complete, stored as data/200708_13.json
# Gameweek 14 complete, stored as data/200708_14.json
# Gameweek 15 complete, stored as data/200708_15.json
# Gameweek 16 complete, stored as data/200708_16.json
# Gameweek 17 complete, stored as data/200708_17.json
# Gameweek 18 complete, stored as data/200708_18.json
# Gameweek 19 complete, stored as data/200708_19.json
# Gameweek 20 complete, stored as data/200708_20.json
# Gameweek 21 complete, stored as data/200708_21.json
# Gameweek 22 complete, stored as data/200708_22.json
# Gameweek 23 complete, stored as data/200708_23.json
# Gameweek 24 complete, stored as data/200708_24.json
# Gameweek 25 complete, stored as data/200708_25.json
# Gameweek 26 complete, stored as data/200708_26.json
# Gameweek 27 complete, stored as data/200708_27.json
# Gameweek 28 complete, stored as data/200708_28.json
# Gameweek 29 complete, stored as data/200708_29.json
# Gameweek 30 complete, stored as data/200708_30.json
# Gameweek 31 complete, stored as data/200708_31.json
# Gameweek 32 complete, stored as data/200708_32.json
# Gameweek 33 complete, stored as data/200708_33.json
# Gameweek 34 complete, stored as data/200708_34.json
# Gameweek 35 complete, stored as data/200708_35.json
# Gameweek 36 complete, stored as data/200708_36.json
# Gameweek 37 complete, stored as data/200708_37.json
# Gameweek 38 complete, stored as data/200708_38.json
# Gameweek 39 complete, stored as data/200708_39.json
# Gameweek 1 complete, stored as data/200809_1.json
# Gameweek 2 complete, stored as data/200809_2.json
# Gameweek 3 complete, stored as data/200809_3.json
# Gameweek 4 complete, stored as data/200809_4.json
# Gameweek 5 complete, stored as data/200809_5.json
# Gameweek 6 complete, stored as data/200809_6.json
# Gameweek 7 complete, stored as data/200809_7.json
# Gameweek 8 complete, stored as data/200809_8.json
# Gameweek 9 complete, stored as data/200809_9.json
# Gameweek 10 complete, stored as data/200809_10.json
# Gameweek 11 complete, stored as data/200809_11.json
# Gameweek 12 complete, stored as data/200809_12.json
# Gameweek 13 complete, stored as data/200809_13.json
# Gameweek 14 complete, stored as data/200809_14.json
# Gameweek 15 complete, stored as data/200809_15.json
# Gameweek 16 complete, stored as data/200809_16.json
# Gameweek 17 complete, stored as data/200809_17.json
# Done
# Took 60595.5 seconds

# %%
chunk2 = [base_url + str(i) for i in range(6500,7500)]
t1 = time.time()
chunk2_yielder = urls_to_json_yield(chunk2)
yield_then_store_by_gameweek(chunk2_yielder)
t2 = time.time()
print("Took {} seconds".format(round(t2-t1,2)))
# Out:
# Gameweek 18 complete, stored as data/200809_18.json
# Gameweek 19 complete, stored as data/200809_19.json
# Gameweek 20 complete, stored as data/200809_20.json
# Gameweek 21 complete, stored as data/200809_21.json
# Gameweek 22 complete, stored as data/200809_22.json
# Gameweek 23 complete, stored as data/200809_23.json
# Gameweek 24 complete, stored as data/200809_24.json
# Gameweek 25 complete, stored as data/200809_25.json
# Done
# Took 2410.47 seconds

# %%
chunk3 = [base_url + str(i) for i in range(6576,7500)]
t1 = time.time()
chunk3_yielder = urls_to_json_yield(chunk3)
yield_then_store_by_gameweek(chunk3_yielder,"26")
t2 = time.time()
print("Took {} seconds".format(round(t2-t1,2)))
# Out:
# Gameweek 26 complete, stored as data/200809_26.json
# Gameweek 27 complete, stored as data/200809_27.json
# Gameweek 28 complete, stored as data/200809_28.json
# Gameweek 29 complete, stored as data/200809_29.json
# Gameweek 30 complete, stored as data/200809_30.json
# Done
# Took 1589.21 seconds

# %%
chunk4 = [base_url + str(i) for i in range(6626,7500)]
t1 = time.time()
chunk4_yielder = urls_to_json_yield(chunk4)
yield_then_store_by_gameweek(chunk4_yielder,"31")
t2 = time.time()
print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
# Out:
# Gameweek 31 complete, stored as data/200809_31.json
# Gameweek 32 complete, stored as data/200809_32.json
# Gameweek 33 complete, stored as data/200809_33.json
# Gameweek 34 complete, stored as data/200809_34.json
# Gameweek 35 complete, stored as data/200809_35.json
# Gameweek 36 complete, stored as data/200809_36.json
# Gameweek 37 complete, stored as data/200809_37.json
# Gameweek 38 complete, stored as data/200809_38.json
# Gameweek 39 complete, stored as data/200809_39.json
# Gameweek 1 complete, stored as data/200910_1.json
# Done
# Took 2764.98 seconds

# %%
chunk5 = [base_url + str(i) for i in range(6717,7500)]
t1 = time.time()
chunk5_yielder = urls_to_json_yield(chunk5)
yield_then_store_by_gameweek(chunk5_yielder,"2")
t2 = time.time()
print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
# Out:
# Gameweek 2 complete, stored as data/200910_2.json
# Gameweek 3 complete, stored as data/200910_3.json
# Gameweek 4 complete, stored as data/200910_4.json
# Gameweek 5 complete, stored as data/200910_5.json
# Gameweek 6 complete, stored as data/200910_6.json
# Gameweek 7 complete, stored as data/200910_7.json
# Gameweek 8 complete, stored as data/200910_8.json
# Gameweek 9 complete, stored as data/200910_9.json
# Gameweek 10 complete, stored as data/200910_10.json
# Gameweek 11 complete, stored as data/200910_11.json
# Gameweek 12 complete, stored as data/200910_12.json
# Gameweek 13 complete, stored as data/200910_13.json
# Gameweek 14 complete, stored as data/200910_14.json
# Gameweek 15 complete, stored as data/200910_15.json
# Gameweek 16 complete, stored as data/200910_16.json
# Gameweek 17 complete, stored as data/200910_17.json
# Gameweek 18 complete, stored as data/200910_18.json
# Gameweek 19 complete, stored as data/200910_19.json
# Gameweek 20 complete, stored as data/200910_20.json
# Gameweek 21 complete, stored as data/200910_21.json
# Gameweek 22 complete, stored as data/200910_22.json
# Gameweek 23 complete, stored as data/200910_23.json
# Gameweek 24 complete, stored as data/200910_24.json
# Gameweek 25 complete, stored as data/200910_25.json
# Gameweek 26 complete, stored as data/200910_26.json
# Gameweek 27 complete, stored as data/200910_27.json
# Gameweek 28 complete, stored as data/200910_28.json
# Gameweek 29 complete, stored as data/200910_29.json
# Gameweek 30 complete, stored as data/200910_30.json
# Gameweek 31 complete, stored as data/200910_31.json
# Gameweek 32 complete, stored as data/200910_32.json
# Gameweek 33 complete, stored as data/200910_33.json
# Gameweek 34 complete, stored as data/200910_34.json
# Gameweek 35 complete, stored as data/200910_35.json
# Gameweek 36 complete, stored as data/200910_36.json
# Gameweek 37 complete, stored as data/200910_37.json
# Gameweek 38 complete, stored as data/200910_38.json
# Gameweek 1 complete, stored as data/201011_1.json
# Gameweek 2 complete, stored as data/201011_2.json
# Gameweek 3 complete, stored as data/201011_3.json
# Gameweek 4 complete, stored as data/201011_4.json
# Gameweek 5 complete, stored as data/201011_5.json
# Gameweek 6 complete, stored as data/201011_6.json
# Gameweek 7 complete, stored as data/201011_7.json
# Gameweek 8 complete, stored as data/201011_8.json
# Gameweek 9 complete, stored as data/201011_9.json
# Gameweek 10 complete, stored as data/201011_10.json
# Gameweek 11 complete, stored as data/201011_11.json
# Gameweek 12 complete, stored as data/201011_12.json
# Gameweek 13 complete, stored as data/201011_13.json
# Gameweek 14 complete, stored as data/201011_14.json
# Gameweek 15 complete, stored as data/201011_15.json
# Gameweek 16 complete, stored as data/201011_16.json
# Gameweek 17 complete, stored as data/201011_17.json
# Gameweek 18 complete, stored as data/201011_18.json
# Gameweek 19 complete, stored as data/201011_19.json
# Gameweek 20 complete, stored as data/201011_20.json
# Gameweek 21 complete, stored as data/201011_21.json
# Gameweek 22 complete, stored as data/201011_22.json
# Gameweek 23 complete, stored as data/201011_23.json
# Gameweek 24 complete, stored as data/201011_24.json
# Gameweek 25 complete, stored as data/201011_25.json
# Gameweek 26 complete, stored as data/201011_26.json
# Gameweek 27 complete, stored as data/201011_27.json
# Gameweek 28 complete, stored as data/201011_28.json
# Gameweek 29 complete, stored as data/201011_29.json
# Gameweek 30 complete, stored as data/201011_30.json
# Gameweek 31 complete, stored as data/201011_31.json
# Gameweek 32 complete, stored as data/201011_32.json
# Gameweek 33 complete, stored as data/201011_33.json
# Gameweek 34 complete, stored as data/201011_34.json
# Gameweek 35 complete, stored as data/201011_35.json
# Gameweek 36 complete, stored as data/201011_36.json
# Gameweek 37 complete, stored as data/201011_37.json
# Gameweek 1 complete, stored as data/201112_1.json
# Gameweek 2 complete, stored as data/201112_2.json
# Gameweek 3 complete, stored as data/201112_3.json
# Final ID Saved: 7499
# Done
# Took 22643.97 seconds = 377.4 mins = 6.29 hours

# %%
chunk6 = [base_url + str(i) for i in range(7496,7900)]
t1 = time.time()
chunk6_yielder = urls_to_json_yield(chunk6)
yield_then_store_by_gameweek(chunk6_yielder,"4")
t2 = time.time()
print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
# Out:
# Gameweek 4 complete, stored as data/201112_4.json
# Gameweek 5 complete, stored as data/201112_5.json
# Gameweek 6 complete, stored as data/201112_6.json
# Gameweek 7 complete, stored as data/201112_7.json
# Gameweek 8 complete, stored as data/201112_8.json
# Gameweek 9 complete, stored as data/201112_9.json
# Gameweek 10 complete, stored as data/201112_10.json
# Gameweek 11 complete, stored as data/201112_11.json
# Gameweek 12 complete, stored as data/201112_12.json
# Gameweek 13 complete, stored as data/201112_13.json
# Gameweek 14 complete, stored as data/201112_14.json
# Gameweek 15 complete, stored as data/201112_15.json
# Gameweek 16 complete, stored as data/201112_16.json
# Gameweek 17 complete, stored as data/201112_17.json
# Gameweek 18 complete, stored as data/201112_18.json
# Gameweek 19 complete, stored as data/201112_19.json
# Gameweek 20 complete, stored as data/201112_20.json
# Gameweek 21 complete, stored as data/201112_21.json
# Gameweek 22 complete, stored as data/201112_22.json
# Gameweek 23 complete, stored as data/201112_23.json
# Gameweek 24 complete, stored as data/201112_24.json
# Gameweek 25 complete, stored as data/201112_25.json
# Gameweek 26 complete, stored as data/201112_26.json
# Gameweek 27 complete, stored as data/201112_27.json
# Gameweek 28 complete, stored as data/201112_28.json
# Gameweek 29 complete, stored as data/201112_29.json
# Gameweek 30 complete, stored as data/201112_30.json
# Gameweek 31 complete, stored as data/201112_31.json
# Gameweek 32 complete, stored as data/201112_32.json
# Gameweek 33 complete, stored as data/201112_33.json
# Gameweek 34 complete, stored as data/201112_34.json
# Gameweek 35 complete, stored as data/201112_35.json
# Gameweek 36 complete, stored as data/201112_36.json
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-c44016e2c657> in <module>
#       2 t1 = time.time()
#       3 chunk6_yielder = urls_to_json_yield(chunk6)
# ----> 4 yield_then_store_by_gameweek(chunk6_yielder,"4")
#       5 t2 = time.time()
#       6 print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
#
# <ipython-input-57-71dadbc153a4> in yield_then_store_by_gameweek(generator_function, first_gameweek)
#       9         json_data = json.loads(json_data_from_generator)
#      10         gameweek_data = json_data["gameweek"]
# ---> 11         gameweek = str(gameweek_data["gameweek"])
#      12         if gameweek == current_gameweek:
#      13             season = gameweek_data["compSeason"]["label"]
#
# KeyError: 'gameweek'

# %%
chunk7 = [base_url + str(i) for i in range(7837,9991)]
t1 = time.time()
chunk7_yielder = urls_to_json_yield(chunk7)
yield_then_store_by_gameweek(chunk7_yielder,"37")
t2 = time.time()
print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
# Out:
# Non prem game found (Id:7847): Competition = AFAPL
# Non prem game found (Id:7848): Competition = AFAPL
# Non prem game found (Id:7849): Competition = AFAPL
# Non prem game found (Id:7850): Competition = AFAPL
# Non prem game found (Id:7851): Competition = AFAPL
# Non prem game found (Id:7852): Competition = AFAPL
# Non prem game found (Id:7853): Competition = AFAPL
# Non prem game found (Id:7854): Competition = AFAPL
# Non prem game found (Id:7855): Competition = AFAPL
# Non prem game found (Id:7856): Competition = AFAPL
# Non prem game found (Id:7857): Competition = AFAPL
# Non prem game found (Id:7858): Competition = AFAPL
# Non prem game found (Id:7859): Competition = AFAPL
# Non prem game found (Id:7860): Competition = AFAPL
# Non prem game found (Id:7861): Competition = AFAPL
# Non prem game found (Id:7862): Competition = AFAPL
# Non prem game found (Id:7863): Competition = AFAPL
# Gameweek 37 complete, stored as data/201112_37.json
# Gameweek 1 complete, stored as data/201213_1.json
# Gameweek 2 complete, stored as data/201213_2.json
# Gameweek 3 complete, stored as data/201213_3.json
# Gameweek 4 complete, stored as data/201213_4.json
# Gameweek 5 complete, stored as data/201213_5.json
# Gameweek 6 complete, stored as data/201213_6.json
# Gameweek 7 complete, stored as data/201213_7.json
# Gameweek 8 complete, stored as data/201213_8.json
# Gameweek 9 complete, stored as data/201213_9.json
# Gameweek 10 complete, stored as data/201213_10.json
# Gameweek 11 complete, stored as data/201213_11.json
# Gameweek 12 complete, stored as data/201213_12.json
# Gameweek 13 complete, stored as data/201213_13.json
# Gameweek 14 complete, stored as data/201213_14.json
# Gameweek 15 complete, stored as data/201213_15.json
# Gameweek 16 complete, stored as data/201213_16.json
# Gameweek 17 complete, stored as data/201213_17.json
# Gameweek 18 complete, stored as data/201213_18.json
# Gameweek 19 complete, stored as data/201213_19.json
# Gameweek 20 complete, stored as data/201213_20.json
# Gameweek 21 complete, stored as data/201213_21.json
# Gameweek 22 complete, stored as data/201213_22.json
# Gameweek 23 complete, stored as data/201213_23.json
# Gameweek 24 complete, stored as data/201213_24.json
# Gameweek 25 complete, stored as data/201213_25.json
# Gameweek 26 complete, stored as data/201213_26.json
# Gameweek 27 complete, stored as data/201213_27.json
# Gameweek 28 complete, stored as data/201213_28.json
# Gameweek 29 complete, stored as data/201213_29.json
# Gameweek 30 complete, stored as data/201213_30.json
# Gameweek 31 complete, stored as data/201213_31.json
# Gameweek 32 complete, stored as data/201213_32.json
# Gameweek 33 complete, stored as data/201213_33.json
# Gameweek 34 complete, stored as data/201213_34.json
# Gameweek 35 complete, stored as data/201213_35.json
# Gameweek 36 complete, stored as data/201213_36.json
# Gameweek 37 complete, stored as data/201213_37.json
# Gameweek 38 complete, stored as data/201213_38.json
# Non prem game found (Id:8244): Competition = AFAPL
# Non prem game found (Id:8245): Competition = AFAPL
# Non prem game found (Id:8246): Competition = AFAPL
# Non prem game found (Id:8247): Competition = AFAPL
# Non prem game found (Id:8248): Competition = AFAPL
# Non prem game found (Id:8249): Competition = AFAPL
# Non prem game found (Id:8250): Competition = AFAPL
# Non prem game found (Id:8251): Competition = AFAPL
# Non prem game found (Id:8252): Competition = AFAPL
# Non prem game found (Id:8253): Competition = AFAPL
# Non prem game found (Id:8254): Competition = AFAPL
# Non prem game found (Id:8255): Competition = AFAPL
# Non prem game found (Id:8256): Competition = AFAPL
# Non prem game found (Id:8257): Competition = AFAPL
# Final ID Saved: 8243
# Done
# Took 7452.49 seconds = 124.21 mins = 2.07 hours

# %%
chunk1315 = [base_url + str(i) for i in range(9231,9991)]
t1 = time.time()
chunk1315_yielder = urls_to_json_yield(chunk1315)
yield_then_store_by_gameweek(chunk1315_yielder,"1")
t2 = time.time()
print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
# Out:
# Gameweek 1 complete, stored as data/201314_1.json
# Gameweek 2 complete, stored as data/201314_2.json
# Gameweek 3 complete, stored as data/201314_3.json
# Final ID Saved: 9266
# Done
# Took 888.38 seconds = 14.81 mins = 0.25 hours

# %%
chunk1315_2 = [base_url + str(i) for i in range(9261,9991)]
t1 = time.time()
chunk1315_2_yielder = urls_to_json_yield(chunk1315_2)
yield_then_store_by_gameweek(chunk1315_2_yielder,"4")
t2 = time.time()
print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
# Out:
# Gameweek 4 complete, stored as data/201314_4.json
# Gameweek 5 complete, stored as data/201314_5.json
# Gameweek 6 complete, stored as data/201314_6.json
# Gameweek 7 complete, stored as data/201314_7.json
# Gameweek 8 complete, stored as data/201314_8.json
# Gameweek 9 complete, stored as data/201314_9.json
# Gameweek 10 complete, stored as data/201314_10.json
# Gameweek 11 complete, stored as data/201314_11.json
# Gameweek 12 complete, stored as data/201314_12.json
# Gameweek 13 complete, stored as data/201314_13.json
# Gameweek 14 complete, stored as data/201314_14.json
# Gameweek 15 complete, stored as data/201314_15.json
# Gameweek 16 complete, stored as data/201314_16.json
# Gameweek 17 complete, stored as data/201314_17.json
# Gameweek 18 complete, stored as data/201314_18.json
# Gameweek 19 complete, stored as data/201314_19.json
# Gameweek 20 complete, stored as data/201314_20.json
# Gameweek 21 complete, stored as data/201314_21.json
# Gameweek 22 complete, stored as data/201314_22.json
# Gameweek 23 complete, stored as data/201314_23.json
# Gameweek 24 complete, stored as data/201314_24.json
# Gameweek 25 complete, stored as data/201314_25.json
# Gameweek 26 complete, stored as data/201314_26.json
# Gameweek 27 complete, stored as data/201314_27.json
# Gameweek 28 complete, stored as data/201314_28.json
# Gameweek 29 complete, stored as data/201314_29.json
# Gameweek 30 complete, stored as data/201314_30.json
# Gameweek 31 complete, stored as data/201314_31.json
# Gameweek 32 complete, stored as data/201314_32.json
# Gameweek 33 complete, stored as data/201314_33.json
# Gameweek 34 complete, stored as data/201314_34.json
# Gameweek 35 complete, stored as data/201314_35.json
# Gameweek 36 complete, stored as data/201314_36.json
# Gameweek 37 complete, stored as data/201314_37.json
# Gameweek 38 complete, stored as data/201314_38.json
# Gameweek 39 complete, stored as data/201314_39.json
# Gameweek 40 complete, stored as data/201314_40.json
# Gameweek 1 complete, stored as data/201415_1.json
# Gameweek 2 complete, stored as data/201415_2.json
# Gameweek 3 complete, stored as data/201415_3.json
# Gameweek 4 complete, stored as data/201415_4.json
# Gameweek 5 complete, stored as data/201415_5.json
# Gameweek 6 complete, stored as data/201415_6.json
# Gameweek 7 complete, stored as data/201415_7.json
# Gameweek 8 complete, stored as data/201415_8.json
# Gameweek 9 complete, stored as data/201415_9.json
# Gameweek 10 complete, stored as data/201415_10.json
# Gameweek 11 complete, stored as data/201415_11.json
# Gameweek 12 complete, stored as data/201415_12.json
# Gameweek 13 complete, stored as data/201415_13.json
# Gameweek 14 complete, stored as data/201415_14.json
# Gameweek 15 complete, stored as data/201415_15.json
# Gameweek 16 complete, stored as data/201415_16.json
# Gameweek 17 complete, stored as data/201415_17.json
# Gameweek 18 complete, stored as data/201415_18.json
# Gameweek 19 complete, stored as data/201415_19.json
# Gameweek 20 complete, stored as data/201415_20.json
# Gameweek 21 complete, stored as data/201415_21.json
# Gameweek 22 complete, stored as data/201415_22.json
# Gameweek 23 complete, stored as data/201415_23.json
# Gameweek 24 complete, stored as data/201415_24.json
# Gameweek 25 complete, stored as data/201415_25.json
# Gameweek 26 complete, stored as data/201415_26.json
# Gameweek 27 complete, stored as data/201415_27.json
# Gameweek 28 complete, stored as data/201415_28.json
# Gameweek 29 complete, stored as data/201415_29.json
# Gameweek 30 complete, stored as data/201415_30.json
# Gameweek 31 complete, stored as data/201415_31.json
# Gameweek 32 complete, stored as data/201415_32.json
# Gameweek 33 complete, stored as data/201415_33.json
# Gameweek 34 complete, stored as data/201415_34.json
# Gameweek 35 complete, stored as data/201415_35.json
# Gameweek 36 complete, stored as data/201415_36.json
# Gameweek 37 complete, stored as data/201415_37.json
# Final ID Saved: 9990
# Done
# Took 16487.42 seconds = 274.79 mins = 4.58 hours

# %%
urls1516 = [base_url + str(i) for i in range(12115,12495)] # 12115 to 12494 inclusive
urls1617 = [base_url + str(i) for i in range(14040,14420)] # 14040 to 14419 inclusive
urls1718 = [base_url + str(i) for i in range(22342,22722)] # 22342 to 22721 inclusive
urls1819 = [base_url + str(i) for i in range(38308,38688)] # 38308 to 38687 inclusive
urls1920 = [base_url + str(i) for i in range(46605,46985)] # 46605 to 46984 inclusive
chunk1517 = urls1516 + urls1617
t1 = time.time()
chunk1517_yielder = urls_to_json_yield(chunk1517)
yield_then_store_by_gameweek(chunk1517_yielder,"1")
t2 = time.time()
print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
# Out:
# Gameweek 1 complete, stored as data/201516_1.json
# Gameweek 2 complete, stored as data/201516_2.json
# Gameweek 3 complete, stored as data/201516_3.json
# Gameweek 4 complete, stored as data/201516_4.json
# Gameweek 5 complete, stored as data/201516_5.json
# Gameweek 6 complete, stored as data/201516_6.json
# Gameweek 7 complete, stored as data/201516_7.json
# Gameweek 8 complete, stored as data/201516_8.json
# Gameweek 9 complete, stored as data/201516_9.json
# Gameweek 10 complete, stored as data/201516_10.json
# Gameweek 11 complete, stored as data/201516_11.json
# Gameweek 12 complete, stored as data/201516_12.json
# Gameweek 13 complete, stored as data/201516_13.json
# Gameweek 14 complete, stored as data/201516_14.json
# Gameweek 15 complete, stored as data/201516_15.json
# Gameweek 16 complete, stored as data/201516_16.json
# Gameweek 17 complete, stored as data/201516_17.json
# Gameweek 18 complete, stored as data/201516_18.json
# Gameweek 19 complete, stored as data/201516_19.json
# Gameweek 20 complete, stored as data/201516_20.json
# Gameweek 21 complete, stored as data/201516_21.json
# Gameweek 22 complete, stored as data/201516_22.json
# Gameweek 23 complete, stored as data/201516_23.json
# Gameweek 24 complete, stored as data/201516_24.json
# Gameweek 25 complete, stored as data/201516_25.json
# Gameweek 26 complete, stored as data/201516_26.json
# Gameweek 27 complete, stored as data/201516_27.json
# Gameweek 28 complete, stored as data/201516_28.json
# Gameweek 29 complete, stored as data/201516_29.json
# Gameweek 30 complete, stored as data/201516_30.json
# Gameweek 31 complete, stored as data/201516_31.json
# Gameweek 32 complete, stored as data/201516_32.json
# Gameweek 33 complete, stored as data/201516_33.json
# Gameweek 34 complete, stored as data/201516_34.json
# Gameweek 35 complete, stored as data/201516_35.json
# Gameweek 36 complete, stored as data/201516_36.json
# Gameweek 37 complete, stored as data/201516_37.json
# Gameweek 38 complete, stored as data/201516_38.json
# Gameweek 1 complete, stored as data/201617_1.json
# Gameweek 2 complete, stored as data/201617_2.json
# Gameweek 28 complete, stored as data/201617_28.json
# Gameweek 2 complete, stored as data/201617_2.json
# Gameweek 3 complete, stored as data/201617_3.json
# Gameweek 4 complete, stored as data/201617_4.json
# Gameweek 5 complete, stored as data/201617_5.json
# Gameweek 6 complete, stored as data/201617_6.json
# Gameweek 7 complete, stored as data/201617_7.json
# Gameweek 8 complete, stored as data/201617_8.json
# Gameweek 9 complete, stored as data/201617_9.json
# Gameweek 10 complete, stored as data/201617_10.json
# Gameweek 11 complete, stored as data/201617_11.json
# Gameweek 12 complete, stored as data/201617_12.json
# Gameweek 13 complete, stored as data/201617_13.json
# Gameweek 14 complete, stored as data/201617_14.json
# Gameweek 15 complete, stored as data/201617_15.json
# Gameweek 16 complete, stored as data/201617_16.json
# Gameweek 17 complete, stored as data/201617_17.json
# Gameweek 18 complete, stored as data/201617_18.json
# Gameweek 19 complete, stored as data/201617_19.json
# Gameweek 20 complete, stored as data/201617_20.json
# Gameweek 21 complete, stored as data/201617_21.json
# Gameweek 22 complete, stored as data/201617_22.json
# Gameweek 23 complete, stored as data/201617_23.json
# Gameweek 24 complete, stored as data/201617_24.json
# Gameweek 25 complete, stored as data/201617_25.json
# Gameweek 26 complete, stored as data/201617_26.json
# Gameweek 34 complete, stored as data/201617_34.json
# Gameweek 36 complete, stored as data/201617_36.json
# Gameweek 26 complete, stored as data/201617_26.json
# Gameweek 27 complete, stored as data/201617_27.json
# Gameweek 34 complete, stored as data/201617_34.json
# Gameweek 28 complete, stored as data/201617_28.json
# Gameweek 2 complete, stored as data/201617_2.json
# Gameweek 37 complete, stored as data/201617_37.json
# Gameweek 34 complete, stored as data/201617_34.json
# Gameweek 28 complete, stored as data/201617_28.json
# Gameweek 27 complete, stored as data/201617_27.json
# Gameweek 34 complete, stored as data/201617_34.json
# Gameweek 37 complete, stored as data/201617_37.json
# Gameweek 29 complete, stored as data/201617_29.json
# Gameweek 30 complete, stored as data/201617_30.json
# Gameweek 31 complete, stored as data/201617_31.json
# Gameweek 32 complete, stored as data/201617_32.json
# Gameweek 33 complete, stored as data/201617_33.json
# Gameweek 37 complete, stored as data/201617_37.json
# Gameweek 34 complete, stored as data/201617_34.json
# Gameweek 37 complete, stored as data/201617_37.json
# Gameweek 34 complete, stored as data/201617_34.json
# Gameweek 37 complete, stored as data/201617_37.json
# Gameweek 34 complete, stored as data/201617_34.json
# Gameweek 35 complete, stored as data/201617_35.json
# Gameweek 36 complete, stored as data/201617_36.json
# Gameweek 37 complete, stored as data/201617_37.json
# Final ID Saved: 14419
# Done
# Took 12109.82 seconds = 201.83 mins = 3.36 hours

# %%
t1 = time.time()
urls1718_yielder = urls_to_json_yield(urls1718)
yield_then_store_by_gameweek(urls1718_yielder,"1")
t2 = time.time()
print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
# Out:
# Gameweek 1 complete, stored as data/201718_1.json
# Gameweek 2 complete, stored as data/201718_2.json
# Gameweek 32 complete, stored as data/201718_32.json
# Gameweek 3 complete, stored as data/201718_3.json
# Gameweek 4 complete, stored as data/201718_4.json
# Gameweek 5 complete, stored as data/201718_5.json
# Gameweek 6 complete, stored as data/201718_6.json
# Gameweek 7 complete, stored as data/201718_7.json
# Gameweek 8 complete, stored as data/201718_8.json
# Gameweek 9 complete, stored as data/201718_9.json
# Gameweek 10 complete, stored as data/201718_10.json
# Gameweek 11 complete, stored as data/201718_11.json
# Gameweek 12 complete, stored as data/201718_12.json
# Gameweek 13 complete, stored as data/201718_13.json
# Gameweek 14 complete, stored as data/201718_14.json
# Gameweek 15 complete, stored as data/201718_15.json
# Gameweek 16 complete, stored as data/201718_16.json
# Gameweek 17 complete, stored as data/201718_17.json
# Gameweek 18 complete, stored as data/201718_18.json
# Gameweek 19 complete, stored as data/201718_19.json
# Gameweek 20 complete, stored as data/201718_20.json
# Gameweek 21 complete, stored as data/201718_21.json
# Gameweek 22 complete, stored as data/201718_22.json
# Gameweek 21 complete, stored as data/201718_21.json
# Gameweek 22 complete, stored as data/201718_22.json
# Gameweek 23 complete, stored as data/201718_23.json
# Gameweek 24 complete, stored as data/201718_24.json
# Gameweek 25 complete, stored as data/201718_25.json
# Gameweek 26 complete, stored as data/201718_26.json
# Gameweek 27 complete, stored as data/201718_27.json
# Final ID Saved: 22619
# Done
# Took 4766.8 seconds = 79.45 mins = 1.32 hours

# %%
urls1718 = [base_url + str(i) for i in range(22342,22722)] # 22342 to 22721 inclusive
urls1819 = [base_url + str(i) for i in range(38308,38688)] # 38308 to 38687 inclusive
urls1920 = [base_url + str(i) for i in range(46605,46985)] # 46605 to 46984 inclusive
urls1718_2 = [base_url + str(i) for i in range(22612,22722)]
t1 = time.time()
urls1718_2_yielder = urls_to_json_yield(urls1718_2)
yield_then_store_by_gameweek(urls1718_2_yielder,"28")
t2 = time.time()
print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
# Out:
# Gameweek 28 complete, stored as data/201718_28.json
# Gameweek 29 complete, stored as data/201718_29.json
# Gameweek 30 complete, stored as data/201718_30.json
# Gameweek 31 complete, stored as data/201718_31.json
# Gameweek 34 complete, stored as data/201718_34.json
# Gameweek 31 complete, stored as data/201718_31.json
# Gameweek 37 complete, stored as data/201718_37.json
# Gameweek 31 complete, stored as data/201718_31.json
# Gameweek 37 complete, stored as data/201718_37.json
# Gameweek 31 complete, stored as data/201718_31.json
# Gameweek 37 complete, stored as data/201718_37.json
# Gameweek 32 complete, stored as data/201718_32.json
# Gameweek 2 complete, stored as data/201718_2.json
# Gameweek 32 complete, stored as data/201718_32.json
# Gameweek 33 complete, stored as data/201718_33.json
# Gameweek 34 complete, stored as data/201718_34.json
# Gameweek 35 complete, stored as data/201718_35.json
# Gameweek 34 complete, stored as data/201718_34.json
# Gameweek 37 complete, stored as data/201718_37.json
# Gameweek 35 complete, stored as data/201718_35.json
# Gameweek 34 complete, stored as data/201718_34.json
# Gameweek 35 complete, stored as data/201718_35.json
# Gameweek 36 complete, stored as data/201718_36.json
# Gameweek 37 complete, stored as data/201718_37.json
# Final ID Saved: 22721
# Done
# Took 2248.8 seconds = 37.48 mins = 0.62 hours

# %%
urls1617 = [base_url + str(i) for i in range(14040,14420)] # 14040 to 14419 inclusive
urls1718 = [base_url + str(i) for i in range(22342,22722)] # 22342 to 22721 inclusive
urls1819 = [base_url + str(i) for i in range(38308,38688)] # 38308 to 38687 inclusive
urls1920 = [base_url + str(i) for i in range(46605,46985)] # 46605 to 46984 inclusive
t1 = time.time()
urls1617_yielder = urls_to_json_yield(urls1617)
yield_then_store_by_gameweek(urls1617_yielder,"1")
t2 = time.time()
print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
# Out:
# Gameweek 1 complete, stored as data/201617_1.json
# Gameweek 2 complete, stored as data/201617_2.json
# Gameweek 28 complete, stored as data/201617_28.json
# Gameweek 2 complete, stored as data/201617_2_.json
# Gameweek 3 complete, stored as data/201617_3.json
# Gameweek 4 complete, stored as data/201617_4.json
# Gameweek 5 complete, stored as data/201617_5.json
# Gameweek 6 complete, stored as data/201617_6.json
# Gameweek 7 complete, stored as data/201617_7.json
# Gameweek 8 complete, stored as data/201617_8.json
# Gameweek 9 complete, stored as data/201617_9.json
# Gameweek 10 complete, stored as data/201617_10.json
# Gameweek 11 complete, stored as data/201617_11.json
# Gameweek 12 complete, stored as data/201617_12.json
# Gameweek 13 complete, stored as data/201617_13.json
# Gameweek 14 complete, stored as data/201617_14.json
# Gameweek 15 complete, stored as data/201617_15.json
# Gameweek 16 complete, stored as data/201617_16.json
# Gameweek 17 complete, stored as data/201617_17.json
# Gameweek 18 complete, stored as data/201617_18.json
# Gameweek 19 complete, stored as data/201617_19.json
# Gameweek 20 complete, stored as data/201617_20.json
# Gameweek 21 complete, stored as data/201617_21.json
# Gameweek 22 complete, stored as data/201617_22.json
# Gameweek 23 complete, stored as data/201617_23.json
# Gameweek 24 complete, stored as data/201617_24.json
# Gameweek 25 complete, stored as data/201617_25.json
# Gameweek 26 complete, stored as data/201617_26.json
# Gameweek 34 complete, stored as data/201617_34.json
# Gameweek 36 complete, stored as data/201617_36.json
# Gameweek 26 complete, stored as data/201617_26_.json
# Gameweek 27 complete, stored as data/201617_27.json
# Gameweek 34 complete, stored as data/201617_34_.json
# Gameweek 28 complete, stored as data/201617_28_.json
# Gameweek 2 complete, stored as data/201617_2__.json
# Gameweek 37 complete, stored as data/201617_37.json
# Gameweek 34 complete, stored as data/201617_34__.json
# Gameweek 28 complete, stored as data/201617_28__.json
# Gameweek 27 complete, stored as data/201617_27_.json
# Gameweek 34 complete, stored as data/201617_34___.json
# Gameweek 37 complete, stored as data/201617_37_.json
# Gameweek 29 complete, stored as data/201617_29.json
# Gameweek 30 complete, stored as data/201617_30.json
# Gameweek 31 complete, stored as data/201617_31.json
# Gameweek 32 complete, stored as data/201617_32.json
# Gameweek 33 complete, stored as data/201617_33.json
# Gameweek 37 complete, stored as data/201617_37__.json
# Gameweek 34 complete, stored as data/201617_34____.json
# Gameweek 37 complete, stored as data/201617_37___.json
# Gameweek 34 complete, stored as data/201617_34_____.json
# Gameweek 37 complete, stored as data/201617_37____.json
# Gameweek 34 complete, stored as data/201617_34______.json
# Gameweek 35 complete, stored as data/201617_35.json
# Gameweek 36 complete, stored as data/201617_36_.json
# Gameweek 37 complete, stored as data/201617_37_____.json
# Final ID Saved: 14419
# Done
# Took 8453.74 seconds = 140.9 mins = 2.35 hours

# %%
t1 = time.time()
rest_of_data = urls1718 + urls1819 + urls1920
rest_yielder = urls_to_json_yield(rest_of_data)
yield_then_store_by_gameweek(rest_yielder,"1")
t2 = time.time()
print("Took {} seconds = {} mins = {} hours".format(round(t2-t1,2) , round((t2-t1)/60,2) , round((t2-t1)/3600,2) ))
# Out:
# Gameweek 1 complete, stored as data/201718_1.json
# Gameweek 2 complete, stored as data/201718_2.json
# Gameweek 32 complete, stored as data/201718_32.json
# Gameweek 3 complete, stored as data/201718_3.json
# Gameweek 4 complete, stored as data/201718_4.json
# Gameweek 5 complete, stored as data/201718_5.json
# Gameweek 6 complete, stored as data/201718_6.json
# Gameweek 7 complete, stored as data/201718_7.json
# Gameweek 8 complete, stored as data/201718_8.json
# Gameweek 9 complete, stored as data/201718_9.json
# Gameweek 10 complete, stored as data/201718_10.json
# Gameweek 11 complete, stored as data/201718_11.json
# Gameweek 12 complete, stored as data/201718_12.json
# Gameweek 13 complete, stored as data/201718_13.json
# Gameweek 14 complete, stored as data/201718_14.json
# Gameweek 15 complete, stored as data/201718_15.json
# Gameweek 16 complete, stored as data/201718_16.json
# Gameweek 17 complete, stored as data/201718_17.json
# Gameweek 18 complete, stored as data/201718_18.json
# Gameweek 19 complete, stored as data/201718_19.json
# Gameweek 20 complete, stored as data/201718_20.json
# Gameweek 21 complete, stored as data/201718_21.json
# Gameweek 22 complete, stored as data/201718_22.json
# Gameweek 21 complete, stored as data/201718_21_.json
# Gameweek 22 complete, stored as data/201718_22_.json
# Gameweek 23 complete, stored as data/201718_23.json
# Gameweek 24 complete, stored as data/201718_24.json
# Gameweek 25 complete, stored as data/201718_25.json
# Gameweek 26 complete, stored as data/201718_26.json
# Gameweek 27 complete, stored as data/201718_27.json
# Gameweek 28 complete, stored as data/201718_28.json
# Gameweek 29 complete, stored as data/201718_29.json
# Gameweek 30 complete, stored as data/201718_30.json
# Gameweek 31 complete, stored as data/201718_31.json
# Gameweek 34 complete, stored as data/201718_34.json
# Gameweek 31 complete, stored as data/201718_31_.json
# Gameweek 37 complete, stored as data/201718_37.json
# Gameweek 31 complete, stored as data/201718_31__.json
# Gameweek 37 complete, stored as data/201718_37_.json
# Gameweek 31 complete, stored as data/201718_31___.json
# Gameweek 37 complete, stored as data/201718_37__.json
# Gameweek 32 complete, stored as data/201718_32_.json
# Gameweek 2 complete, stored as data/201718_2_.json
# Gameweek 32 complete, stored as data/201718_32__.json
# Gameweek 33 complete, stored as data/201718_33.json
# Gameweek 34 complete, stored as data/201718_34_.json
# Gameweek 35 complete, stored as data/201718_35.json
# Gameweek 34 complete, stored as data/201718_34__.json
# Gameweek 37 complete, stored as data/201718_37___.json
# Gameweek 35 complete, stored as data/201718_35_.json
# Gameweek 34 complete, stored as data/201718_34___.json
# Gameweek 35 complete, stored as data/201718_35__.json
# Gameweek 36 complete, stored as data/201718_36.json
# Gameweek 37 complete, stored as data/201718_37____.json
# Gameweek 38 complete, stored as data/201718_38.json
# Gameweek 1 complete, stored as data/201819_1.json
# Gameweek 2 complete, stored as data/201819_2.json
# Gameweek 3 complete, stored as data/201819_3.json
# Gameweek 4 complete, stored as data/201819_4.json
# Gameweek 5 complete, stored as data/201819_5.json
# Gameweek 6 complete, stored as data/201819_6.json
# Gameweek 7 complete, stored as data/201819_7.json
# Gameweek 8 complete, stored as data/201819_8.json
# Gameweek 9 complete, stored as data/201819_9.json
# Gameweek 10 complete, stored as data/201819_10.json
# Gameweek 11 complete, stored as data/201819_11.json
# Gameweek 12 complete, stored as data/201819_12.json
# Gameweek 13 complete, stored as data/201819_13.json
# Gameweek 14 complete, stored as data/201819_14.json
# Gameweek 15 complete, stored as data/201819_15.json
# Gameweek 16 complete, stored as data/201819_16.json
# Gameweek 17 complete, stored as data/201819_17.json
# Gameweek 18 complete, stored as data/201819_18.json
# Gameweek 19 complete, stored as data/201819_19.json
# Gameweek 20 complete, stored as data/201819_20.json
# Gameweek 21 complete, stored as data/201819_21.json
# Gameweek 22 complete, stored as data/201819_22.json
# Gameweek 23 complete, stored as data/201819_23.json
# Gameweek 24 complete, stored as data/201819_24.json
# Gameweek 25 complete, stored as data/201819_25.json
# Gameweek 26 complete, stored as data/201819_26.json
# Gameweek 27 complete, stored as data/201819_27.json
# Gameweek 32 complete, stored as data/201819_32.json
# Gameweek 25 complete, stored as data/201819_25_.json
# Gameweek 27 complete, stored as data/201819_27_.json
# Gameweek 28 complete, stored as data/201819_28.json
# Gameweek 29 complete, stored as data/201819_29.json
# Gameweek 30 complete, stored as data/201819_30.json
# Gameweek 31 complete, stored as data/201819_31.json
# Gameweek 34 complete, stored as data/201819_34.json
# Gameweek 31 complete, stored as data/201819_31_.json
# Gameweek 35 complete, stored as data/201819_35.json
# Gameweek 32 complete, stored as data/201819_32_.json
# Gameweek 35 complete, stored as data/201819_35_.json
# Gameweek 31 complete, stored as data/201819_31__.json
# Gameweek 35 complete, stored as data/201819_35__.json
# Gameweek 32 complete, stored as data/201819_32__.json
# Gameweek 33 complete, stored as data/201819_33.json
# Gameweek 32 complete, stored as data/201819_32___.json
# Gameweek 33 complete, stored as data/201819_33_.json
# Gameweek 35 complete, stored as data/201819_35___.json
# Gameweek 32 complete, stored as data/201819_32____.json
# Gameweek 34 complete, stored as data/201819_34_.json
# Gameweek 35 complete, stored as data/201819_35____.json
# Gameweek 36 complete, stored as data/201819_36.json
# Gameweek 37 complete, stored as data/201819_37.json
# Gameweek 38 complete, stored as data/201819_38.json
# Gameweek 1 complete, stored as data/201920_1.json
# Gameweek 2 complete, stored as data/201920_2.json
# Gameweek 3 complete, stored as data/201920_3.json
# Gameweek 4 complete, stored as data/201920_4.json
# Gameweek 5 complete, stored as data/201920_5.json
# Gameweek 6 complete, stored as data/201920_6.json
# Gameweek 7 complete, stored as data/201920_7.json
# Gameweek 8 complete, stored as data/201920_8.json
# Gameweek 9 complete, stored as data/201920_9.json
# Gameweek 10 complete, stored as data/201920_10.json
# Gameweek 11 complete, stored as data/201920_11.json
# Gameweek 12 complete, stored as data/201920_12.json
# Gameweek 13 complete, stored as data/201920_13.json
# Gameweek 14 complete, stored as data/201920_14.json
# Gameweek 15 complete, stored as data/201920_15.json
# Gameweek 16 complete, stored as data/201920_16.json
# Gameweek 17 complete, stored as data/201920_17.json
# Gameweek 18 complete, stored as data/201920_18.json
# Gameweek 24 complete, stored as data/201920_24.json
# Gameweek 19 complete, stored as data/201920_19.json
# Gameweek 20 complete, stored as data/201920_20.json
# Gameweek 21 complete, stored as data/201920_21.json
# Gameweek 22 complete, stored as data/201920_22.json
# Gameweek 23 complete, stored as data/201920_23.json
# Gameweek 24 complete, stored as data/201920_24_.json
# Gameweek 25 complete, stored as data/201920_25.json
# Gameweek 26 complete, stored as data/201920_26.json
# Gameweek 27 complete, stored as data/201920_27.json
# Gameweek 30 complete, stored as data/201920_30.json
# Gameweek 28 complete, stored as data/201920_28.json
# Gameweek 30 complete, stored as data/201920_30_.json
# Gameweek 28 complete, stored as data/201920_28_.json
# Gameweek 29 complete, stored as data/201920_29.json
# Gameweek 30 complete, stored as data/201920_30__.json
# Gameweek 31 complete, stored as data/201920_31.json
# Gameweek 32 complete, stored as data/201920_32.json
# Gameweek 33 complete, stored as data/201920_33.json
# Gameweek 34 complete, stored as data/201920_34.json
# Gameweek 35 complete, stored as data/201920_35.json
# Gameweek 36 complete, stored as data/201920_36.json
# Gameweek 37 complete, stored as data/201920_37.json
# Final ID Saved: 46984
# Done
# Took 21989.9 seconds = 366.5 mins = 6.11 hours
