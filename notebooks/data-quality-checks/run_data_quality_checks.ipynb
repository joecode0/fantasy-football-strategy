# %%
import pandas as pd
import time
import ast

# %%
def run_data_quality_checks_per_row(row):
    goal_count, outcome = check_goals_and_outcome(row)
    home_lineup, away_lineup = check_lineups(row)
    check = ""
    if goal_count == False:
        check += "goal_count "
    if outcome == False:
        check += "outcome "
    if home_lineup == False:
        check += "home_lineup "
    if away_lineup == False:
        check += "away_lineup"
    
    return check

def check_lineups(row):
    home = False
    away = False
    home_lineup = len(ast.literal_eval(row["home_lineup"]))
    away_lineup = len(ast.literal_eval(row["away_lineup"]))
    if home_lineup == 11:
        home = True
    if away_lineup == 11:
        away = True
    return home, away
        
def check_goals_and_outcome(row):
    goal_count = False
    outcome = False
    expected_home_goals = row["hScore"]
    expected_away_goals = row["aScore"]
    expected_total_goals = expected_home_goals + expected_away_goals
    actual_goals = len(ast.literal_eval(row["goals"]))
    if actual_goals == expected_total_goals:
        goal_count = True
    given_outcome = row["outcome"]
    if expected_home_goals > expected_away_goals:
        if given_outcome == "H":
            outcome = True
    elif expected_home_goals == expected_away_goals:
        if given_outcome == "D":
            outcome = True
    else:
        if given_outcome == "A":
            outcome = True
    return goal_count, outcome

# %%
def run_overall_quality_checks(df):
    for season in set(df["season"].tolist()):
        df_season = df.query("season == @season")
        print("Season {} has {} games".format(season,len(df_season)))
        for gameweek in set(df_season["gameweek"].tolist()):
            df_gameweek = df_season.query("gameweek == @gameweek")
            if len(df_gameweek) != 10:
                print("Gameweek {} of season {} has {} games".format(gameweek,season,len(df_gameweek)))

# %%
df = pd.read_csv("C:/Users/joeco/Python/fantasy-football-strategy/data-cleaning/data_outputs/all_prem_data_cleaned.csv")
df["checks"] = df.apply(run_data_quality_checks_per_row,axis=1)
run_overall_quality_checks(df)
df.to_csv("all_prem_cleaned_with_initial_quality_checks.csv",index=False)
# Out:
# Season 12/13 has 380 games
# Gameweek 1 of season 12/13 has 11 games
# Gameweek 2 of season 12/13 has 9 games
# Gameweek 3 of season 12/13 has 9 games
# Gameweek 16 of season 12/13 has 11 games
# Gameweek 17 of season 12/13 has 9 games
# Gameweek 19 of season 12/13 has 9 games
# Gameweek 22 of season 12/13 has 11 games
# Gameweek 23 of season 12/13 has 11 games
# Gameweek 26 of season 12/13 has 11 games
# Gameweek 27 of season 12/13 has 9 games
# Gameweek 29 of season 12/13 has 6 games
# Gameweek 33 of season 12/13 has 7 games
# Gameweek 34 of season 12/13 has 4 games
# Gameweek 37 of season 12/13 has 13 games
# Season 11/12 has 380 games
# Gameweek 1 of season 11/12 has 9 games
# Gameweek 19 of season 11/12 has 21 games
# Gameweek 25 of season 11/12 has 9 games
# Gameweek 27 of season 11/12 has 11 games
# Gameweek 28 of season 11/12 has 4 games
# Gameweek 29 of season 11/12 has 5 games
# Gameweek 32 of season 11/12 has 20 games
# Gameweek 33 of season 11/12 has 6 games
# Gameweek 34 of season 11/12 has 11 games
# Gameweek 35 of season 11/12 has 14 games
# Season 17/18 has 380 games
# Gameweek 21 of season 17/18 has 9 games
# Gameweek 22 of season 17/18 has 11 games
# Gameweek 31 of season 17/18 has 4 games
# Gameweek 34 of season 17/18 has 14 games
# Gameweek 35 of season 17/18 has 6 games
# Gameweek 37 of season 17/18 has 16 games
# Season 10/11 has 380 games
# Gameweek 16 of season 10/11 has 9 games
# Gameweek 17 of season 10/11 has 13 games
# Gameweek 18 of season 10/11 has 18 games
# Gameweek 20 of season 10/11 has 11 games
# Gameweek 22 of season 10/11 has 13 games
# Gameweek 25 of season 10/11 has 14 games
# Gameweek 26 of season 10/11 has 9 games
# Gameweek 27 of season 10/11 has 11 games
# Gameweek 31 of season 10/11 has 6 games
# Gameweek 32 of season 10/11 has 3 games
# Gameweek 33 of season 10/11 has 12 games
# Gameweek 35 of season 10/11 has 11 games
# Season 14/15 has 380 games
# Gameweek 27 of season 14/15 has 8 games
# Gameweek 28 of season 14/15 has 11 games
# Gameweek 31 of season 14/15 has 11 games
# Gameweek 33 of season 14/15 has 7 games
# Gameweek 34 of season 14/15 has 12 games
# Gameweek 37 of season 14/15 has 11 games
# Season 08/09 has 376 games
# Gameweek 3 of season 08/09 has 9 games
# Gameweek 18 of season 08/09 has 5 games
# Gameweek 21 of season 08/09 has 9 games
# Gameweek 25 of season 08/09 has 12 games
# Gameweek 27 of season 08/09 has 8 games
# Gameweek 28 of season 08/09 has 12 games
# Gameweek 33 of season 08/09 has 7 games
# Gameweek 34 of season 08/09 has 3 games
# Gameweek 37 of season 08/09 has 11 games
# Season 16/17 has 380 games
# Gameweek 26 of season 16/17 has 8 games
# Gameweek 27 of season 16/17 has 11 games
# Gameweek 28 of season 16/17 has 4 games
# Gameweek 34 of season 16/17 has 11 games
# Gameweek 36 of season 16/17 has 11 games
# Gameweek 37 of season 16/17 has 15 games
# Season 19/20 has 380 games
# Gameweek 18 of season 19/20 has 9 games
# Gameweek 24 of season 19/20 has 11 games
# Gameweek 28 of season 19/20 has 8 games
# Gameweek 30 of season 19/20 has 12 games
# Season 09/10 has 380 games
# Gameweek 2 of season 09/10 has 6 games
# Gameweek 11 of season 09/10 has 11 games
# Gameweek 13 of season 09/10 has 12 games
# Gameweek 17 of season 09/10 has 8 games
# Gameweek 18 of season 09/10 has 9 games
# Gameweek 19 of season 09/10 has 24 games
# Gameweek 20 of season 09/10 has 12 games
# Gameweek 21 of season 09/10 has 8 games
# Gameweek 22 of season 09/10 has 12 games
# Gameweek 24 of season 09/10 has 12 games
# Gameweek 25 of season 09/10 has 11 games
# Gameweek 26 of season 09/10 has 8 games
# Gameweek 27 of season 09/10 has 8 games
# Gameweek 28 of season 09/10 has 11 games
# Gameweek 30 of season 09/10 has 5 games
# Gameweek 33 of season 09/10 has 6 games
# Gameweek 34 of season 09/10 has 4 games
# Gameweek 35 of season 09/10 has 11 games
# Gameweek 37 of season 09/10 has 12 games
# Season 06/07 has 380 games
# Gameweek 2 of season 06/07 has 8 games
# Gameweek 5 of season 06/07 has 11 games
# Gameweek 14 of season 06/07 has 9 games
# Gameweek 15 of season 06/07 has 6 games
# Gameweek 16 of season 06/07 has 13 games
# Gameweek 17 of season 06/07 has 12 games
# Gameweek 21 of season 06/07 has 9 games
# Gameweek 24 of season 06/07 has 11 games
# Gameweek 25 of season 06/07 has 8 games
# Gameweek 27 of season 06/07 has 12 games
# Gameweek 28 of season 06/07 has 8 games
# Gameweek 29 of season 06/07 has 12 games
# Gameweek 33 of season 06/07 has 6 games
# Gameweek 34 of season 06/07 has 8 games
# Gameweek 35 of season 06/07 has 5 games
# Gameweek 38 of season 06/07 has 12 games
# Season 13/14 has 380 games
# Gameweek 1 of season 13/14 has 11 games
# Gameweek 3 of season 13/14 has 9 games
# Gameweek 26 of season 13/14 has 8 games
# Gameweek 28 of season 13/14 has 8 games
# Gameweek 29 of season 13/14 has 5 games
# Gameweek 32 of season 13/14 has 5 games
# Gameweek 35 of season 13/14 has 8 games
# Gameweek 36 of season 13/14 has 3 games
# Gameweek 39 of season 13/14 has 13 games
# Season 18/19 has 380 games
# Gameweek 25 of season 18/19 has 11 games
# Gameweek 27 of season 18/19 has 8 games
# Gameweek 31 of season 18/19 has 5 games
# Gameweek 32 of season 18/19 has 15 games
# Gameweek 33 of season 18/19 has 6 games
# Gameweek 34 of season 18/19 has 11 games
# Gameweek 35 of season 18/19 has 14 games
# Season 07/08 has 380 games
# Gameweek 2 of season 07/08 has 7 games
# Gameweek 14 of season 07/08 has 11 games
# Gameweek 15 of season 07/08 has 11 games
# Gameweek 23 of season 07/08 has 11 games
# Gameweek 24 of season 07/08 has 9 games
# Gameweek 27 of season 07/08 has 9 games
# Gameweek 28 of season 07/08 has 11 games
# Gameweek 29 of season 07/08 has 6 games
# Gameweek 30 of season 07/08 has 3 games
# Gameweek 31 of season 07/08 has 12 games
# Gameweek 35 of season 07/08 has 11 games
# Gameweek 36 of season 07/08 has 9 games
# Season 15/16 has 380 games
# Gameweek 27 of season 15/16 has 8 games
# Gameweek 30 of season 15/16 has 5 games
# Gameweek 33 of season 15/16 has 11 games
# Gameweek 34 of season 15/16 has 15 games
# Gameweek 35 of season 15/16 has 7 games
# Gameweek 37 of season 15/16 has 14 games

# %%
df["checks"].value_counts()
# Out:
#                 5309
# home_lineup        4
# away_lineup        3
# Name: checks, dtype: int64

# %%
home_lineup = "home_lineup "
away_lineup = "away_lineup"
df_home_lineups = df.query("checks == @home_lineup")
df_home_lineups.head()
# Out:
#       match_id  gameweek season      kickoff_time            hName  hScore  \
# 4023     14267        23  16/17  01-02-2017 19:45  West Ham United       0
# 4029     14273        24  16/17  04-02-2017 15:00        Hull City       2
# 4040     14287        25  16/17  11-02-2017 15:00       Sunderland       0
# 4049     14293        26  16/17  25-02-2017 15:00        Hull City       1
#
#       aScore            aName outcome  \
# 4023       4  Manchester City       A
# 4029       0        Liverpool       H
# 4040       4      Southampton       A
# 4049       1          Burnley       D
#
#                                             home_lineup  \
# 4023  [{'pos': 'D', 'id': 8897}, {'pos': 'D', 'id': ...
# 4029  [{'pos': 'M', 'id': 6494}, {'pos': 'M', 'id': ...
# 4040  [{'pos': 'D', 'id': 1717}, {'pos': 'M', 'id': ...
# 4049  [{'pos': 'M', 'id': 3066}, {'pos': 'D', 'id': ...
#
#                                              home_bench  \
# 4023  [{'pos': 'F', 'id': 13145}, {'pos': 'G', 'id':...
# 4029  [{'pos': 'M', 'id': 3066}, {'pos': 'F', 'id': ...
# 4040  [{'pos': 'D', 'id': 4918}, {'pos': 'M', 'id': ...
# 4049  [{'pos': 'F', 'id': 10460}, {'pos': 'F', 'id':...
#
#                                             away_lineup  \
# 4023  [{'pos': 'M', 'id': 4316}, {'pos': 'D', 'id': ...
# 4029  [{'pos': 'F', 'id': 13511}, {'pos': 'M', 'id':...
# 4040  [{'pos': 'M', 'id': 3811}, {'pos': 'D', 'id': ...
# 4049  [{'pos': 'D', 'id': 3999}, {'pos': 'D', 'id': ...
#
#                                              away_bench  \
# 4023  [{'pos': 'M', 'id': 3799}, {'pos': 'D', 'id': ...
# 4029  [{'pos': 'D', 'id': 7219}, {'pos': 'D', 'id': ...
# 4040  [{'pos': 'G', 'id': 20494}, {'pos': 'F', 'id':...
# 4049  [{'pos': 'M', 'id': 8242}, {'pos': 'F', 'id': ...
#
#                                                   goals  \
# 4023  [{'time': "17'00", 'type': 'Goal', 'scorer_id'...
# 4029  [{'time': "44'00", 'type': 'Goal', 'scorer_id'...
# 4040  [{'time': "30'00", 'type': 'Goal', 'scorer_id'...
# 4049  [{'time': "72'00", 'type': 'Pen', 'scorer_id':...
#
#                                                    subs  \
# 4023  [{'time': "64'00", 'type': 'Sub', 'desc': 'ON'...
# 4029  [{'time': "62'00", 'type': 'Sub', 'desc': 'ON'...
# 4040  [{'time': "45'00", 'type': 'Sub', 'desc': 'ON'...
# 4049  [{'time': "67'00", 'type': 'Sub', 'desc': 'ON'...
#
#                                                   cards  \
# 4023  [{'time': "19'00", 'type': 'Yellow Card', 'pla...
# 4029  [{'time': "27'00", 'type': 'Yellow Card', 'pla...
# 4040  [{'time': "90 +4'00", 'type': 'Yellow Card', '...
# 4049  [{'time': "40'00", 'type': 'Yellow Card', 'pla...
#
#                                                  phases pen_misses  \
# 4023  [{'time': "00'00", 'type': 'Half Start'}, {'ti...         []
# 4029  [{'time': "00'00", 'type': 'Half Start'}, {'ti...         []
# 4040  [{'time': "00'00", 'type': 'Half Start'}, {'ti...         []
# 4049  [{'time': "00'00", 'type': 'Half Start'}, {'ti...         []
#
#             checks
# 4023  home_lineup
# 4029  home_lineup
# 4040  home_lineup
# 4049  home_lineup
